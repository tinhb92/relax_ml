# %% [markdown]
# <a href="https://colab.research.google.com/github/tinhb92/relax_ml/blob/master/synthetic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# data consisted of number
# so can create some decent synthetic data of any form
# any fake data from scratch to play around
# fake image with black and white also can
# to play around without loading data

# %% [markdown]
# Random images

# %%
from pylab import imshow, show, get_cmap
from numpy import random

Z = random.random((80,50))   # Test data

imshow(Z, cmap=get_cmap("Spectral"), interpolation='nearest')
show()

# %%
import pylab as plt
import numpy as np

Z = np.random.random((500,500))   # Test data
plt.imshow(Z, cmap='gray', interpolation='nearest')
plt.show()

# %%
pip install pydbgen
# Out:
# ...
#      |████████████████████████████████| 81kB 3.9MB/s
# ...
#      |████████████████████████████████| 880kB 10.3MB/s
# ...
#      |████████████████████████████████| 81kB 29.2MB/s
# ERROR: python-slugify 3.0.3 has requirement text-unidecode==1.2, but you'll have text-unidecode 1.3 which is incompatible.
# ...
#   Found existing installation: text-unidecode 1.2
#     Uninstalling text-unidecode-1.2:
#       Successfully uninstalled text-unidecode-1.2
# ...

# %% [markdown]
# Random Tabular

# %%
import pydbgen
from pydbgen import pydbgen
myDB=pydbgen.pydb()

# %%
myDB.city_real()
# Out:
# 'Murry Hill'

# %%
for _ in range(10):
    print(myDB.license_plate())
# Out:
# QWE-7915
# 3CID215
# NCY-731
# 5KOI876
# MJY-9501
# ZRK-937
# JID-701
# 6CXC982
# DNR-5550
# XWA-2082

# %%
testdf=myDB.gen_dataframe(20,['name','city','phone','date'])
testdf
# Out:
#                        name             city  phone-number        date
# 0            Tina Fernandez         Sarasota  364-601-2773  2000-09-04
# 1            Kenneth Hoover  Waimanalo Beach  534-442-5877  1972-06-15
# 2            Deanna Roberts             Dawn  673-074-4752  1979-04-08
# 3               James Boyer          Triumph  360-180-6925  2009-04-10
# 4             Natalie Mayer       Grandfalls  526-698-6874  2012-04-01
# 5   Mrs. Angel Williams DVM     Iron Station  535-337-8360  2011-01-21
# 6            Henry Browning     Proctorville  356-438-0004  2003-07-24
# 7             Maria Huffman     Prophetstown  645-095-1009  1997-07-22
# 8             Kevin Skinner        Monkstown  164-752-4062  1977-12-09
# 9              Adam Mcguire         Rushmere  796-641-1787  1986-10-06
# 10            David Parsons         Coalgate  267-622-1139  1992-05-01
# 11           Marissa Berger         Engadine  446-259-0386  1972-12-19
# ...

# %%
myDB.gen_dataframe??

# %%
myDB.gen_table(db_file='Testdb.DB',table_name='People',
fields=['name','city','street_address','email'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-48b8c526fe04> in <module>()
#       1 myDB.gen_table(db_file='Testdb.DB',table_name='People',
# ----> 2 fields=['name','city','street_address','email'])
#
# /usr/local/lib/python3.6/dist-packages/pydbgen/pydbgen.py in gen_table(self, num, fields, db_file, table_name, primarykey, real_email, real_city, phone_simple, seed)
#     428
#     429         # Create a temporary df
# --> 430         temp_df = self.gen_dataframe(num=num,fields=fields,real_email=real_email,real_city=real_city,phone_simple=phone_simple)
#     431         # Use the dataframe to insert into the table
#     432         for i in range(num):
#
# /usr/local/lib/python3.6/dist-packages/pydbgen/pydbgen.py in gen_dataframe(self, num, fields, real_email, real_city, phone_simple, seed)
#     343
# ...

# %% [markdown]
# Random text

# %%
import random
import string

# digits = "".join( [random.choice(string.digits) for i in range(8)] )
chars = "".join( [random.choice(string.ascii_letters) for i in range(150)] )

# %%
print(chars)
# Out:
# wIxvtrzgSgPCLvXMXdQlNCLPjYOMMLcVobqUkFWBrpxOjpNfxZtYBKlapjMPkvxwtFJaruBPWTzcooNZAlHxkGcvJtNYHaICrFsehEWCZCzezbeXlXFuWGKywUzQecQHcIlOlQbqJwSIZfOHNuAcwJ

# %%
print(digits + chars)
# Out:
# 77769038xcfKfdlOxZMOeUZ

# %% [markdown]
# Synthetic based on rnn, neural nets
